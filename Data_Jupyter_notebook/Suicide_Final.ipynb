# %%
import pandas as pd
import numpy as np
import os

# %%
# IMPORTING CSV FILE-Education
education_data = os.path.join('..', 'Final Project','Clean Data', 'Education_clean.csv')
education_df = pd.read_csv(education_data)
education_df.head()
# Out:
#   LocationTime LOCATION  TIME  Edu_val_BUPPSRY  Edu_val_TRY  Edu_val_UPPSRY
# 0     ARG-2004      ARG  2004        51.205463    16.711861       32.082676
# 1     ARG-2005      ARG  2005        50.157974    17.471054       32.370968
# 2     ARG-2006      ARG  2006        48.472809    17.830963       33.696232
# 3     ARG-2008      ARG  2008        45.804825    18.973812       35.221363
# 4     ARG-2009      ARG  2009        44.794254    19.518599       35.687149

# %%
# IMPORTING CSV FILE-Employment
employment_data = os.path.join('..', 'Final Project','Clean Data', 'employment_clean.csv')
employment_df = pd.read_csv(employment_data)
employment_df.head()
# Out:
#   LocationTime LOCATION  TIME  employment_val_MEN_PC_WKGPOP  \
# 0     AUS-1990      AUS  1990                      79.21233
# 1  AUS-1990-01      AUS  1990                      80.09801
# 2  AUS-1990-02      AUS  1990                      79.71510
# 3  AUS-1990-03      AUS  1990                      79.68172
# 4  AUS-1990-04      AUS  1990                      79.58195
#
#    employment_val_MEN_THND_PER  employment_val_TOT_PC_WKGPOP  \
# 0                     4600.225                      68.37136
# 1                     4615.454                      68.70767
# 2                     4606.212                      68.62899
# 3                     4609.215                      68.70557
# 4                     4612.217                      68.63134
#
#    employment_val_TOT_THND_PER  employment_val_WOMEN_PC_WKGPOP  \
# 0                     7858.817                        57.37470
# 1                     7839.257                        57.14748
# ...

# %%
# IMPORTING CSV FILE-Alcohol
alcohol_data = os.path.join('..', 'Final Project','Clean Data', 'alcohol_clean.csv')
alcohol_df = pd.read_csv(alcohol_data)
alcohol_df.head()
# Out:
#   LocationTime LOCATION  TIME  Alcohol_val
# 0     AUS-1990      AUS  1990         10.6
# 1     AUS-1991      AUS  1991         10.1
# 2     AUS-1992      AUS  1992          9.9
# 3     AUS-1993      AUS  1993         10.2
# 4     AUS-1994      AUS  1994         10.0

# %%
# IMPORTING CSV FILE-Health Spending
health_spend_data = os.path.join('..', 'Final Project','Clean Data', 'health_spending_clean.csv')
health_spend_df = pd.read_csv(health_spend_data)
health_spend_df.head()
# Out:
#   LocationTime LOCATION  hSpend_val_COMPULSORY  hSpend_val_OOPEXP  \
# 0     ALB-2000      ALB                 38.617             60.402
# 1     ALB-2001      ALB                 39.272             57.776
# 2     ALB-2002      ALB                 37.946             59.709
# 3     ALB-2003      ALB                 41.983             54.015
# 4     ALB-2004      ALB                 44.248             52.658
#
#    hSpend_val_TOT  hSpend_val_VOLUNTARY
# 0             NaN                61.383
# 1             NaN                60.728
# 2             NaN                62.054
# 3             NaN                58.017
# 4             NaN                55.752

# %%
# IMPORTING CSV FILE-Obesity
obesity_data = os.path.join('..', 'Final Project','Clean Data', 'obesity_clean.csv')
obesity_df = pd.read_csv(obesity_data)
obesity_df.head()
# Out:
#   LocationTime LOCATION  TIME  obesity_val_MEASURED  obesity_val_SELFREPORTED
# 0     AUS-1995      AUS  1995                  59.2                      38.7
# 1     AUS-2001      AUS  2001                   NaN                      50.0
# 2     AUS-2004      AUS  2004                   NaN                      53.5
# 3     AUS-2007      AUS  2007                  61.2                      56.0
# 4     AUS-2011      AUS  2011                  63.4                       NaN

# %%
# IMPORTING CSV FILE-Poverty
poverty_data = os.path.join('..', 'Final Project','Clean Data', 'poverty_clean.csv')
poverty_df = pd.read_csv(poverty_data)
poverty_df.head()
# Out:
#   LocationTime LOCATION  TIME  Poverty_Value_0_17  Poverty_Value_18_65  \
# 0     AUS-2012      AUS  2012               0.129                0.107
# 1     AUS-2014      AUS  2014               0.130                0.102
# 2     AUS-2016      AUS  2016               0.125                0.094
# 3     AUS-2018      AUS  2018               0.133                0.096
# 4     AUS-2020      AUS  2020               0.133                0.101
#
#    Poverty_Value_66MORE  Poverty_Value_TOT
# 0                 0.335              0.140
# 1                 0.257              0.128
# 2                 0.232              0.121
# 3                 0.237              0.124
# 4                 0.226              0.126

# %%
# IMPORTING CSV FILE-Smoking
smoking_data = os.path.join('..', 'Final Project','Clean Data', 'smoking_clean.csv')
smoking_df = pd.read_csv(smoking_data)
smoking_df.head()
# Out:
#   LocationTime LOCATION  TIME  smoking_val
# 0     AUS-1992      AUS  1992         26.0
# 1     AUS-1995      AUS  1995         24.1
# 2     AUS-1998      AUS  1998         22.1
# 3     AUS-2001      AUS  2001         19.6
# 4     AUS-2004      AUS  2004         17.8

# %%
# IMPORTING CSV FILE-Social Spending
social_spend_data = os.path.join('..', 'Final Project','Clean Data', 'social_spending_clean.csv')
social_spend_df = pd.read_csv(social_spend_data)
social_spend_df.head()
# Out:
#   LocationTime LOCATION  TIME  Value_PRIV_PC_GDP  Value_PUB_PC_GDP  \
# 0     AUS-1990      AUS  1990              1.096            13.141
# 1     AUS-1991      AUS  1991              1.204            14.306
# 2     AUS-1992      AUS  1992              1.236            15.285
# 3     AUS-1993      AUS  1993              1.397            15.545
# 4     AUS-1994      AUS  1994              1.419            15.271
#
#    Value_PUB_USD_CAP  Value_PUBNET_PC_GDP  Value_TOTNET_PC_GDP
# 0           3928.253                  NaN                  NaN
# 1           4239.755                  NaN                  NaN
# 2           4659.895                  NaN                  NaN
# 3           4884.162                  NaN                  NaN
# 4           4934.387                  NaN                  NaN

# %%
# IMPORTING CSV FILE-Social Support
social_supp_data = os.path.join('..', 'Final Project','Clean Data', 'social_support_clean.csv')
social_supp_df = pd.read_csv(social_supp_data)
social_supp_df.head()
# Out:
#   LocationTime LOCATION  TIME  Social_spt_val
# 0     AUS-2010      AUS  2010       92.938334
# 1     AUS-2011      AUS  2011       92.938334
# 2     AUS-2012      AUS  2012       92.938334
# 3     AUS-2013      AUS  2013       92.938334
# 4     AUS-2014      AUS  2014       92.938334

# %%
# IMPORTING CSV FILE-Suicide OECD
suicide_oecd_data = os.path.join('..', 'Final Project','Clean Data', 'suicide_oecd_clean.csv')
suicide_oecd_df = pd.read_csv(suicide_oecd_data)
suicide_oecd_df.head()
# Out:
#   LocationTime LOCATION  TIME  Suicide_val_MEN  Suicide_val_TOT  \
# 0     ARG-1990      ARG  1990             15.3              9.3
# 1     ARG-1991      ARG  1991             13.8              8.2
# 2     ARG-1992      ARG  1992             15.8              9.0
# 3     ARG-1993      ARG  1993             16.8              9.3
# 4     ARG-1994      ARG  1994             15.4              8.7
#
#    Suicide_val_WOMEN
# 0                4.6
# 1                3.8
# 2                3.7
# 3                3.6
# 4                3.5

# %%
# Merge DF
df1 = pd.merge(education_df, employment_df, how='outer')
display(df1)
# Out:
#      LocationTime LOCATION  TIME  Edu_val_BUPPSRY  Edu_val_TRY  \
# 0        ARG-2004      ARG  2004        51.205463    16.711861
# 1        ARG-2005      ARG  2005        50.157974    17.471054
# 2        ARG-2006      ARG  2006        48.472809    17.830963
# 3        ARG-2008      ARG  2008        45.804825    18.973812
# 4        ARG-2009      ARG  2009        44.794254    19.518599
# ...           ...      ...   ...              ...          ...
# 8442  ZAF-2019-Q4      ZAF  2019              NaN          NaN
# 8443  ZAF-2020-Q1      ZAF  2020              NaN          NaN
# 8444  ZAF-2020-Q2      ZAF  2020              NaN          NaN
# 8445  ZAF-2020-Q3      ZAF  2020              NaN          NaN
# 8446  ZAF-2020-Q4      ZAF  2020              NaN          NaN
#
#       Edu_val_UPPSRY  employment_val_MEN_PC_WKGPOP  \
# 0          32.082676                           NaN
# 1          32.370968                           NaN
# 2          33.696232                           NaN
# ...

# %%
# Merge DF
df2 = pd.merge(health_spend_df, obesity_df, how='outer')
display(df2)
# Out:
#      LocationTime LOCATION  hSpend_val_COMPULSORY  hSpend_val_OOPEXP  \
# 0        ALB-2000      ALB                 38.617             60.402
# 1        ALB-2001      ALB                 39.272             57.776
# 2        ALB-2002      ALB                 37.946             59.709
# 3        ALB-2003      ALB                 41.983             54.015
# 4        ALB-2004      ALB                 44.248             52.658
# ...           ...      ...                    ...                ...
# 1369     EST-1998      EST                    NaN                NaN
# 1370     IDN-1993      IDN                    NaN                NaN
# 1371     IDN-2014      IDN                    NaN                NaN
# 1372     LVA-1998      LVA                    NaN                NaN
# 1373     RUS-2005      RUS                    NaN                NaN
#
#       hSpend_val_TOT  hSpend_val_VOLUNTARY    TIME  obesity_val_MEASURED  \
# ...

# %%
# Merge DF
df3 = pd.merge(poverty_df, smoking_df, how='outer')
display(df3)
# Out:
#      LocationTime LOCATION  TIME  Poverty_Value_0_17  Poverty_Value_18_65  \
# 0        AUS-2012      AUS  2012               0.129                0.107
# 1        AUS-2014      AUS  2014               0.130                0.102
# 2        AUS-2016      AUS  2016               0.125                0.094
# 3        AUS-2016      AUS  2016               0.125                0.094
# 4        AUS-2016      AUS  2016               0.125                0.094
# ...           ...      ...   ...                 ...                  ...
# 2219     PER-2019      PER  2019                 NaN                  NaN
# 2220     PER-2019      PER  2019                 NaN                  NaN
# 2221     PER-2020      PER  2020                 NaN                  NaN
# 2222     PER-2020      PER  2020                 NaN                  NaN
# 2223     PER-2020      PER  2020                 NaN                  NaN
#
#       Poverty_Value_66MORE  Poverty_Value_TOT  smoking_val
# ...

# %%
# Merge DF
df4 = pd.merge(social_spend_df, social_supp_df, how='outer')
display(df4)
# Out:
#      LocationTime LOCATION  TIME  Value_PRIV_PC_GDP  Value_PUB_PC_GDP  \
# 0        AUS-1990      AUS  1990              1.096            13.141
# 1        AUS-1991      AUS  1991              1.204            14.306
# 2        AUS-1992      AUS  1992              1.236            15.285
# 3        AUS-1993      AUS  1993              1.397            15.545
# 4        AUS-1994      AUS  1994              1.419            15.271
# ...           ...      ...   ...                ...               ...
# 1154     ZAF-2015      ZAF  2015                NaN               NaN
# 1155     ZAF-2016      ZAF  2016                NaN               NaN
# 1156     ZAF-2017      ZAF  2017                NaN               NaN
# 1157     ZAF-2018      ZAF  2018                NaN               NaN
# 1158     ZAF-2019      ZAF  2019                NaN               NaN
#
#       Value_PUB_USD_CAP  Value_PUBNET_PC_GDP  Value_TOTNET_PC_GDP  \
# ...

# %%
# Merge DF
df5 = pd.merge(suicide_oecd_df, alcohol_df, how='outer')
display(df5)
# Out:
#      LocationTime LOCATION  TIME  Suicide_val_MEN  Suicide_val_TOT  \
# 0        ARG-1990      ARG  1990             15.3              9.3
# 1        ARG-1991      ARG  1991             13.8              8.2
# 2        ARG-1992      ARG  1992             15.8              9.0
# 3        ARG-1993      ARG  1993             16.8              9.3
# 4        ARG-1994      ARG  1994             15.4              8.7
# ...           ...      ...   ...              ...              ...
# 1494     ZAF-1994      ZAF  1994              NaN              NaN
# 1495     ZAF-1995      ZAF  1995              NaN              NaN
# 1496     ZAF-2019      ZAF  2019              NaN              NaN
# 1497     HRV-2018      HRV  2018              NaN              NaN
# 1498     PER-2019      PER  2019              NaN              NaN
#
#       Suicide_val_WOMEN  Alcohol_val
# 0                   4.6          NaN
# 1                   3.8          NaN
# 2                   3.7          NaN
# ...

# %%
# Merge DF
df6 = pd.merge(df1, df2, how='outer')
display(df6)
# Out:
#      LocationTime LOCATION    TIME  Edu_val_BUPPSRY  Edu_val_TRY  \
# 0        ARG-2004      ARG  2004.0        51.205463    16.711861
# 1        ARG-2005      ARG  2005.0        50.157974    17.471054
# 2        ARG-2006      ARG  2006.0        48.472809    17.830963
# 3        ARG-2008      ARG  2008.0        45.804825    18.973812
# 4        ARG-2009      ARG  2009.0        44.794254    19.518599
# ...           ...      ...     ...              ...          ...
# 9369     ZAF-2015      ZAF     NaN              NaN          NaN
# 9370     ZAF-2016      ZAF     NaN              NaN          NaN
# 9371     ZAF-2017      ZAF     NaN              NaN          NaN
# 9372     ZAF-2018      ZAF     NaN              NaN          NaN
# 9373     ZAF-2019      ZAF     NaN              NaN          NaN
#
#       Edu_val_UPPSRY  employment_val_MEN_PC_WKGPOP  \
# 0          32.082676                           NaN
# 1          32.370968                           NaN
# ...

# %%
# Merge DF
df7 = pd.merge(df3, df4, how='outer')
display(df7)
# Out:
#      LocationTime LOCATION  TIME  Poverty_Value_0_17  Poverty_Value_18_65  \
# 0        AUS-2012      AUS  2012               0.129                0.107
# 1        AUS-2014      AUS  2014               0.130                0.102
# 2        AUS-2016      AUS  2016               0.125                0.094
# 3        AUS-2016      AUS  2016               0.125                0.094
# 4        AUS-2016      AUS  2016               0.125                0.094
# ...           ...      ...   ...                 ...                  ...
# 2583     ZAF-2011      ZAF  2011                 NaN                  NaN
# 2584     ZAF-2012      ZAF  2012                 NaN                  NaN
# 2585     ZAF-2013      ZAF  2013                 NaN                  NaN
# 2586     ZAF-2014      ZAF  2014                 NaN                  NaN
# 2587     ZAF-2016      ZAF  2016                 NaN                  NaN
#
#       Poverty_Value_66MORE  Poverty_Value_TOT  smoking_val  Value_PRIV_PC_GDP  \
# ...

# %%
# Merge DF
df8 = pd.merge(df6, df7, how='outer')
display(df8)
# Out:
#       LocationTime LOCATION    TIME  Edu_val_BUPPSRY  Edu_val_TRY  \
# 0         ARG-2004      ARG  2004.0        51.205463    16.711861
# 1         ARG-2005      ARG  2005.0        50.157974    17.471054
# 2         ARG-2005      ARG  2005.0        50.157974    17.471054
# 3         ARG-2005      ARG  2005.0        50.157974    17.471054
# 4         ARG-2006      ARG  2006.0        48.472809    17.830963
# ...            ...      ...     ...              ...          ...
# 10784     POL-1991      POL  1991.0              NaN          NaN
# 10785     SVN-1995      SVN  1995.0              NaN          NaN
# 10786     TUR-1990      TUR  1990.0              NaN          NaN
# 10787     TUR-1993      TUR  1993.0              NaN          NaN
# 10788     TUR-1996      TUR  1996.0              NaN          NaN
#
#        Edu_val_UPPSRY  employment_val_MEN_PC_WKGPOP  \
# 0           32.082676                           NaN
# 1           32.370968                           NaN
# ...

# %%
# Merge ALL DF
df9 = pd.merge(df8, df5, how='outer')
display(df9)
# Out:
#       LocationTime LOCATION    TIME  Edu_val_BUPPSRY  Edu_val_TRY  \
# 0         ARG-2004      ARG  2004.0        51.205463    16.711861
# 1         ARG-2005      ARG  2005.0        50.157974    17.471054
# 2         ARG-2005      ARG  2005.0        50.157974    17.471054
# 3         ARG-2005      ARG  2005.0        50.157974    17.471054
# 4         ARG-2006      ARG  2006.0        48.472809    17.830963
# ...            ...      ...     ...              ...          ...
# 11002     ZAF-1992      ZAF  1992.0              NaN          NaN
# 11003     ZAF-1993      ZAF  1993.0              NaN          NaN
# 11004     ZAF-1994      ZAF  1994.0              NaN          NaN
# 11005     ZAF-1995      ZAF  1995.0              NaN          NaN
# 11006     HRV-2018      HRV  2018.0              NaN          NaN
#
#        Edu_val_UPPSRY  employment_val_MEN_PC_WKGPOP  \
# 0           32.082676                           NaN
# 1           32.370968                           NaN
# ...

# %%
# NUMBER of EMPTY ROWS
df9.isnull().sum()
# Out:
# LocationTime                          0
# LOCATION                              0
# TIME                                927
# Edu_val_BUPPSRY                    8993
# Edu_val_TRY                        8982
# Edu_val_UPPSRY                     9052
# employment_val_MEN_PC_WKGPOP       3289
# employment_val_MEN_THND_PER        1949
# employment_val_TOT_PC_WKGPOP       3281
# employment_val_TOT_THND_PER        1566
# employment_val_WOMEN_PC_WKGPOP     3289
# employment_val_WOMEN_THND_PER      1945
# hSpend_val_COMPULSORY              8874
# hSpend_val_OOPEXP                  8993
# hSpend_val_TOT                     8891
# hSpend_val_VOLUNTARY               8877
# obesity_val_MEASURED              10585
# obesity_val_SELFREPORTED          10050
# Poverty_Value_0_17                 9972
# Poverty_Value_18_65                9972
# Poverty_Value_66MORE               9972
# Poverty_Value_TOT                  9972
# smoking_val                        9010
# ...

# %%
df9.dropna()
display(df9)
# Out:
#       LocationTime LOCATION    TIME  Edu_val_BUPPSRY  Edu_val_TRY  \
# 0         ARG-2004      ARG  2004.0        51.205463    16.711861
# 1         ARG-2005      ARG  2005.0        50.157974    17.471054
# 2         ARG-2005      ARG  2005.0        50.157974    17.471054
# 3         ARG-2005      ARG  2005.0        50.157974    17.471054
# 4         ARG-2006      ARG  2006.0        48.472809    17.830963
# ...            ...      ...     ...              ...          ...
# 11002     ZAF-1992      ZAF  1992.0              NaN          NaN
# 11003     ZAF-1993      ZAF  1993.0              NaN          NaN
# 11004     ZAF-1994      ZAF  1994.0              NaN          NaN
# 11005     ZAF-1995      ZAF  1995.0              NaN          NaN
# 11006     HRV-2018      HRV  2018.0              NaN          NaN
#
#        Edu_val_UPPSRY  employment_val_MEN_PC_WKGPOP  \
# 0           32.082676                           NaN
# 1           32.370968                           NaN
# ...

# %%
# Save in a new csv file
df9.to_csv('Suicide_Final.csv', index=False)
