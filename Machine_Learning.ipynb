# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
#import the data
#view top 10 
suicide_data= pd.read_csv("Machine_learning/Suicide-noDup.csv")
suicide_data.head(10)
# Out:
#   LocationTime  Suicide_val_TOT  Alcohol_val  Edu_val_BUPPSRY  Edu_val_TRY  \
# 0     ARG-1990              9.3     9.371017        29.599914    28.372829
# 1     ARG-1991              8.2     9.371017        29.599914    28.372829
# 2     ARG-1992              9.0     9.371017        29.599914    28.372829
# 3     ARG-1993              9.3     9.371017        29.599914    28.372829
# 4     ARG-1994              8.7     9.371017        29.599914    28.372829
# 5     ARG-1995              8.4     9.371017        29.599914    28.372829
# 6     ARG-1996              8.4     9.371017        29.599914    28.372829
# 7     ARG-1997              8.1     9.371017        29.599914    28.372829
# 8     ARG-1998              8.4     9.371017        29.599914    28.372829
# 9     ARG-1999              8.4     9.371017        29.599914    28.372829
#
#    Edu_val_UPPSRY  employment_val_TOT_PC_WKGPOP  employment_val_TOT_THND_PER  \
# ...

# %%
suicide_predict=suicide_data.drop(columns=["LocationTime", "Edu_val_BUPPSRY", "employment_val_TOT_PC_WKGPOP","hSpend_val_OOPEXP","Poverty_Value_18_65","Poverty_Value_66MORE","Value_PRIV_PC_GDP" ])
suicide_predict
# Out:
#       Suicide_val_TOT  Alcohol_val  Edu_val_TRY  Edu_val_UPPSRY  \
# 0                 9.3     9.371017    28.372829       42.537433
# 1                 8.2     9.371017    28.372829       42.537433
# 2                 9.0     9.371017    28.372829       42.537433
# 3                 9.3     9.371017    28.372829       42.537433
# 4                 8.7     9.371017    28.372829       42.537433
# ...               ...          ...          ...             ...
# 1326              1.2     7.200000    12.759739       27.709494
# 1327              1.0     7.200000    13.034455       27.603758
# 1328              0.8     7.300000    13.804585       27.984232
# 1329              0.7     7.300000    15.495651       28.569286
# 1330              0.6     7.200000    15.387996       29.314827
#
#       employment_val_TOT_THND_PER  hSpend_val_COMPULSORY  hSpend_val_TOT  \
# 0                    16354.280433             596.529764     1156.064582
# ...

# %%
X = suicide_predict.drop(columns="Suicide_val_TOT")

# %%
#plt.scatter(suicide_predict.Value_PUB_PC_GDP, suicide_predict.Suicide_val_TOT)
#plt.xlabel('Factors')
#plt.ylabel('Suicide')
#plt.show()

# %%
#X = suicide_predict.Value_PUB_PC_GDP.values.reshape(-1, 1)

# %%
#X[:5]

# %%
X.shape
# Out:
# (1331, 16)

# %%
y = suicide_predict.Suicide_val_TOT

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (1331,)

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [ 1.36656844e+00  1.52820043e-01  1.29888798e-01 -5.38862704e-06
#   8.74533104e-03 -5.21998697e-03  7.77283009e-03 -2.48335414e-01
#  -3.76809405e+01  3.96090785e+01 -2.88435894e-02  7.25027505e-02
#  -6.45716913e-04  5.60005541e-02 -1.14286680e-01 -2.06564603e-01]
# 26.420312857587504

# %%
#Split into test and train
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
   y, random_state=1)

# %%
classifier = LinearRegression
classifier
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12208\3959894982.py in <module>
# ----> 1 classifier.fit(X_train, y_train)
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %%
predictions = classifier.predict(X_test)
pd.DataFrame({"Prediction": predictions, "Actual": y_test})

# %%
y = suicide_predict["Suicide_val_TOT"]
X = suicide_predict.drop(columns="Suicide_val_TOT")

# %%
X = suicide_predict.values.reshape(-1, 1)
