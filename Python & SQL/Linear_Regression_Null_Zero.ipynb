# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
from sklearn import linear_model 
import statsmodels.api as sm 
from sklearn.preprocessing import StandardScaler 
import numpy as np

# %%
df = pd.read_csv('Final/Suicide_Final_Zero.csv')
df
# Out:
#      LocationTime  Suicide_Val_TOT  Alcohol_Val  Edu_Sec_Val  Edu_Try_Val  \
# 0        ARG-1990              9.3          9.5         52.0         31.3
# 1        ARG-1991              8.2          8.4         53.6         30.8
# 2        ARG-1992              9.0          8.2         61.8         33.0
# 3        ARG-1993              9.3          7.5         59.4         33.7
# 4        ARG-1994              8.7         10.0         45.8         36.1
# ...           ...              ...          ...          ...          ...
# 1326     ZAF-2014              1.2          7.2         59.5         12.8
# 1327     ZAF-2015              1.0          7.2         59.4         13.0
# 1328     ZAF-2016              0.8          7.3         58.2         13.8
# 1329     ZAF-2017              0.7          7.3         55.9         15.5
# 1330     ZAF-2018              0.6          7.2         55.3         15.4
#
#       Emp_Val  Healthy_Spend_Val  Obesity_Val  Smoking_Val  Soc_Spend_Val  \
# 0         0.0               25.8          0.0          0.0            0.0
# 1         0.0               26.1         61.8         13.4            0.0
# 2        86.7               25.5         59.4         12.1            2.0
# 3        87.2               24.6         45.8         11.3            1.9
# 4        87.5               24.3         52.3         10.8            1.9
# ...       ...                ...          ...          ...            ...
# 1326     81.7               29.2         64.0         26.0           12.1
# 1327     81.3               29.0         71.0         26.0           12.2
# 1328     79.5               29.1         65.7          0.0           12.5
# 1329     78.7               28.9         66.2          0.0           12.6
# 1330     79.0               28.8         73.1         20.3           18.7
#
#       Work_Hour_Val
# 0            1854.0
# 1            1845.6
# 2            1855.7
# 3            1874.2
# 4            1870.3
# ...             ...
# 1326         1778.4
# 1327         1777.6
# 1328         1781.6
# 1329         1777.2
# 1330            0.0
#
# [1331 rows x 11 columns]

# %%
# Spliting target variable and independent variables
X = df.drop(['Suicide_Val_TOT', 'LocationTime'], axis = 1).values.reshape(-1, 9)
y = df['Suicide_Val_TOT']

# %%
# Splitting to training and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7, test_size = 0.3, random_state = 100)

# %%
# Create a StandardScaler instance
scaler = StandardScaler()
# Fit the StandardScaler
X_scaler = scaler.fit(X_train)
# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
#Linear Regression
model= LinearRegression()
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
X_train_scaled
# Out:
# array([[ 1.2596093 , -1.11926909,  0.91578594, ...,  0.87636401,
#          1.67456418,  0.68661316],
#        [ 0.29955057, -0.52090871,  1.53052074, ..., -0.60183311,
#         -0.77876184,  0.18339778],
#        [ 1.56930567,  0.58960757, -0.15999994, ..., -1.72046877,
#         -0.31587014,  0.53493113],
#        ...,
#        [ 0.67118621, -1.02799378, -0.8070892 , ...,  0.55675383,
#         -0.59360516,  0.31991161],
#        [ 0.79506475, -0.50569616,  0.25251946, ..., -1.72046877,
#         -0.26958097, -0.17428484],
#        [-0.41275108, -0.20144512,  1.10991272, ...,  0.65663201,
#         -0.15385804,  0.29223989]])

# %%
# Adding constant
X_train_scaled = sm.add_constant(X_train_scaled)

# %%
#Running model 
lm = sm.OLS(y_train,X_train_scaled).fit()

# %%
#Summary
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Suicide_Val_TOT   R-squared:                       0.248
# Model:                            OLS   Adj. R-squared:                  0.241
# Method:                 Least Squares   F-statistic:                     33.82
# Date:                Sat, 04 Feb 2023   Prob (F-statistic):           1.13e-51
# Time:                        13:29:09   Log-Likelihood:                -3177.9
# No. Observations:                 931   AIC:                             6376.
# Df Residuals:                     921   BIC:                             6424.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.9855      0.242     57.757      0.000      13.510      14.461
# x1             3.2951      0.247     13.318      0.000       2.810       3.781
# x2            -1.2470      0.266     -4.684      0.000      -1.770      -0.725
# x3             0.8481      0.285      2.976      0.003       0.289       1.407
# x4            -0.2315      0.263     -0.880      0.379      -0.748       0.285
# x5            -0.1070      0.277     -0.386      0.700      -0.651       0.437
# x6            -0.5623      0.251     -2.238      0.025      -1.055      -0.069
# x7             0.8992      0.248      3.631      0.000       0.413       1.385
# x8            -0.9617      0.256     -3.757      0.000      -1.464      -0.459
# x9            -1.1922      0.248     -4.817      0.000      -1.678      -0.706
# ==============================================================================
# Omnibus:                      295.402   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              966.231
# Skew:                           1.539   Prob(JB):                    1.53e-210
# Kurtosis:                       6.929   Cond. No.                         1.94
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_pred = model.predict(X_test_scaled) 
y_pred
# Out:
# array([14.7286577 , 22.49449033, 13.90674188,  5.30272518,  6.24407951,
#        18.25369834, 16.6668898 , 18.43048871, 11.05407731, 15.57471256,
#        19.35851004, 15.11033667, 11.63098516, 14.79304202, 22.01510305,
#         9.05301452, 18.13959763, 17.70453603,  9.72020211, 12.71346745,
#        12.64675389, 11.14457097, 18.48705426, 15.66577483, 19.39420752,
#        15.59124851, 19.28569717,  8.8032566 , 19.44789161, 14.82998992,
#        23.5089368 , 13.5800568 , 17.84903525, 11.84816755, 11.29115161,
#        14.28883534, 13.35015379, 16.15267847, 14.94829126,  2.99188072,
#        15.0249121 , 18.17466875, 16.07127818, 12.31413142, 20.86003227,
#         5.07188198,  9.26840557, 18.918068  , 18.28438074,  5.76544994,
#        11.26474281, 11.39617417, 14.053244  ,  4.498477  , 19.49187293,
#        15.27269735, 16.04259993, 14.5305072 , 11.07628889, 14.04740516,
#        14.63909595, 13.6587443 , 19.18719781, 13.36975764, 12.30053343,
#        13.5935911 ,  9.42113245,  0.14853525, 18.49409083,  4.66475176,
#        18.68839379, 12.95549504, 17.30387862, 10.07014331, 13.13547181,
#         8.15622992, 14.36583956, 12.32962646, 19.50993989, 16.99017391,
#        13.94627567, 16.77036605, 14.57451274, 14.18917569, 10.32112464,
#        15.31290459, 13.15521434, 18.78099002, 12.14142105, 16.69978137,
#         9.20915205, 10.57056892, 18.96262777, 16.8590935 , 14.59825112,
#         8.23173314,  5.50802685, 16.37894034, 12.04219038, 19.86386709,
#        14.02247777, 12.97929903, 13.88297231, 14.75524376, 13.35635996,
#        16.2703831 , 15.96181614, 12.65581828, 10.23065766, 13.93211774,
#         5.96398209, 15.21247791, 12.63776384, 15.92842154, 14.35331899,
#        11.69646685, 15.58476517, 11.22837179, 13.91961727, 14.4362415 ,
#        16.9030969 , 14.8404614 , 16.01428269, 16.95408352, 14.5086372 ,
#        15.06825359, 12.27831677, 16.46541365, 10.30408488, 20.94619887,
#        14.48744087, 17.15887329, 16.38037172, 15.97438311, 12.05792113,
#        17.9439397 , 14.58419349,  8.59137914, 11.67091201, 11.54120524,
#        11.63783753, 14.53232131, 11.39053321, 14.75756172, 13.65556382,
#        10.52900063, 15.0983795 , 13.45122682, 12.49988638, 19.35702888,
#         4.27396302, 15.7145203 , 18.28814941, 15.42646853, 11.63034399,
#        16.31095664, 16.1922191 ,  9.15889034, 10.87531759, 15.48465767,
#        17.2424142 ,  5.42956711,  7.37612234, 17.95798514, 18.51563734,
#        11.64987019, 16.52295183, 16.09655859,  6.06170558,  9.01299156,
#        13.87624206, 16.9177647 , 21.30254527, 15.00651672, 13.44887032,
#        13.54468593,  9.81722443, 17.24314689,  9.4280895 , 13.89680441,
#        11.27332878,  5.17866982, 16.0107211 , 15.53962658, 23.87909976,
#        13.56904339, 18.01085634, 18.69535786, 18.23976555, 14.1872597 ,
#         5.81663768, 13.74996667, 14.50832665,  1.11279204, 16.12402435,
#         6.25241855, 18.86037269,  9.8946239 , 11.82737269,  5.83518573,
#        21.98898738,  4.75412977, 18.2646002 ,  8.22380775, 17.08322798])

# %%
from sklearn.metrics import r2_score 
r2_score(y_test, y_pred)
# Out:
# 0.20245997233060087

# %%
pred_y_df=pd.DataFrame({"Actual Value":y_test, "Predicted Value":y_pred, "Difference":y_test-y_pred})
pred_y_df[0:20]
# Out:
#       Actual Value  Predicted Value  Difference
# 560            7.0        14.728658   -7.728658
# 1208          31.0        22.494490    8.505510
# 222           19.7        13.906742    5.793258
# 315            8.7         5.302725    3.397275
# 731            7.3         6.244080    1.055920
# 888           10.5        18.253698   -7.753698
# 139           11.0        16.666890   -5.666890
# 459           39.4        18.430489   20.969511
# 256           11.9        11.054077    0.845923
# 238           11.1        15.574713   -4.474713
# 330           22.3        19.358510    2.941490
# 1084          15.4        15.110337    0.289663
# 1290          11.3        11.630985   -0.330985
# 1027          13.7        14.793042   -1.093042
# 858           32.9        22.015103   10.884897
# 157            5.5         9.053015   -3.553015
# 401           14.6        18.139598   -3.539598
# 534           15.1        17.704536   -2.604536
# 571            3.9         9.720202   -5.820202
# 1056           1.0        12.713467  -11.713467

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred) 
plt.yticks(np.arange(0, 51, step=5)) 
plt.xticks(np.arange(0,51, step=5))
fig.suptitle('Predicted vs Actual', fontsize=20)              
plt.xlabel('Actual', fontsize=18)                          
plt.ylabel('Predicted', fontsize=16)
# Out:
# Text(0, 0.5, 'Predicted')
